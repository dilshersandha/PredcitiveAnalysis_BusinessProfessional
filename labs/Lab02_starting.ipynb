# %% [markdown]
# <a href="https://colab.research.google.com/github/Dong2Yo/PredcitiveAnalysis_BusinessProfessional/blob/main/labs/Lab02_starting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![lab2_01.GIF](data:image/gif;base64,...)

# %%
# Write your program here.

# %% [markdown]
# ![lab2_02.GIF](data:image/gif;base64,...)

# %%
# Write your program here.

# %% [markdown]
# ![lab2_03.GIF](data:image/gif;base64,...)

# %%
# Write your program here.

# %% [markdown]
# ![lab2_04.GIF](data:image/gif;base64,...)

# %%
# Write your program here.

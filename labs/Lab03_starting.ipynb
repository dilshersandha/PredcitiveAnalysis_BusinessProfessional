# %% [markdown]
# <a href="https://colab.research.google.com/github/Dong2Yo/PredcitiveAnalysis_BusinessProfessional/blob/main/labs/Lab03_starting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dataset: [titanic.csv ](https://github.com/Dong2Yo/PredcitiveAnalysis_BusinessProfessional/blob/main/data/titanic.csv![lab3_01.GIF](data:image/gif;base64,...))

# %% [markdown]
# ![lab3_01.GIF](data:image/gif;base64,...)

# %%
# Write your program here.

# %% [markdown]
# ![lab3_02.GIF](data:image/gif;base64,...)

# %%
# Write your program here.

# %% [markdown]
# ![lab3_03.GIF](data:image/gif;base64,...)

# %%
# Write your program here.

# %% [markdown]
# ![lab3_04.GIF](data:image/gif;base64,...)

# %%
# Write your program here.
